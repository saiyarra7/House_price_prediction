TERS GREEN PH 1B 02</td><td>69</td><td>69</td><td>179900</td><td>126.6</td><td>12/1/2015</td><td>172500</td><td>121.39</td><td>2/1/2016</td><td>None</td></tr><tr><td>8</td><td>Sold</td><td>17762 OAK BRIDGE ST</td><td>3</td><td>2</td><td>0</td><td>2</td><td>1419</td><td>2</td><td>Shingle</td><td>5720</td><td>1995</td><td>Community</td><td>null</td><td>HUNTER'S GREEN PH 2A</td><td>128</td><td>128</td><td>189000</td><td>133.19</td><td>1/11/2017</td><td>175000</td><td>123.33</td><td>3/31/2017</td><td>None</td></tr><tr><td>9</td><td>Sold</td><td>18112  ASHTON PARK WAY </td><td>3</td><td>2</td><td>0</td><td>2</td><td>1856</td><td>2</td><td>Shingle</td><td>5950</td><td>1997</td><td>Community</td><td>null</td><td>HUNTERS GREEN</td><td>57</td><td>57</td><td>185500</td><td>99.95</td><td>8/4/2015</td><td>178000</td><td>95.91</td><td>10/14/2015</td><td>Bank Owned/REO</td></tr><tr><td>10</td><td>Sold</td><td>17727 OAK BRIDGE ST</td><td>3</td><td>2</td><td>0</td><td>2</td><td>1670</td><td>2</td><td>Tile</td><td>5662</td><td>1996</td><td>Community</td><td>null</td><td>HUNTERS GREEN PH 2B</td><td>0</td><td>0</td><td>17 ...

# %% [markdown]
# #Exploratory Analysis

# %%
import pandas as pd
dfp=df.toPandas()
dfp.isna().sum()
# Out:
# Out[16]: slnoskm                     0
# Status                      0
# Address                     0
# Beds                        0
# bathsfull                   0
# bathshalf                   0
# bathstotal                  0
# sqft                        0
# garages                     4
# Roof                        0
# lotsqft                     0
# yrblt                       0
# Pool                        0
# spa                       313
# subdivn                     0
# adom_agentdaysonmarket      0
# cdom_cumuldaysmls           0
# listprice                   0
# lppersqft                   0
# PendingDate                 0
# pricesold                   0
# sppersqft                   0
# datesold                    0
# splsale                     0
# dtype: int64

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   slnoskm                 482 non-null    int32
#  1   Status                  482 non-null    object
#  2   Address                 482 non-null    object
#  3   Beds                    482 non-null    int32
#  4   bathsfull               482 non-null    int32
#  5   bathshalf               482 non-null    int32
#  6   bathstotal              482 non-null    int32
#  7   sqft                    482 non-null    int32
#  8   garages                 478 non-null    float64
#  9   Roof                    482 non-null    object
#  10  lotsqft                 482 non-null    int32
#  11  yrblt                   482 non-null    int32
#  12  Pool                    482 non-null    object
#  13  spa                     169 non-null    object
#  14  subdivn                 482 non-null    object
#  15  adom_agentdaysonmarket  482 non-null    int32
#  16  cdom_cumuldaysmls       482 non-null    int32
#  17  listprice               482 non-null    int32
#  18  lppersqft               482 non-null    float64
#  19  PendingDate             482 non-null    object
#  20  pricesold               482 non-null    int32
#  21  sppersqft               482 non-null    float64
#  22  datesold                482 non-null    object
#  23  splsale                 482 non-null    object
# dtypes: float64(3), int32(12), object(9)
# memory usage: 67.9+ KB

# %%
dfp.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>slnoskm</th>
#       <th>Beds</th>
#       <th>bathsfull</th>
#       <th>bathshalf</th>
#       <th>bathstotal</th>
#       <th>sqft</th>
#       <th>garages</th>
#       <th>lotsqft</th>
#       <th>yrblt</th>
#       <th>adom_agentdaysonmarket</th>
#       <th>cdom_cumuldaysmls</th>
#       <th>listprice</th>
#       <th>lppersqft</th>
#       <th>pricesold</th>
#       <th>sppersqft</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td
</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #Feature Engineering

# %%
from pyspark.sql.functions import *

df = df.withColumn("baths",col("bathsfull")+.5*col("bathshalf"))


from pyspark.sql.functions import when
df=df.withColumn("specialsale", when(df.splsale == 'None', 0)
.otherwise(1))


df=df.withColumn("tileroof", when(df.Roof == 'Title', 1)
.when(df.Roof == 'Slate', 1)
.when(df.Roof == 'Slate,Title', 1)
.when(df.Roof == 'Concrete,Title', 1)
.otherwise(0))



df=df.withColumn("privatepool", when(df.Pool == 'Private', 1)
.when(df.Pool == 'Private,Community', 1)
.otherwise(0))
df=df.withColumn("communitypool", when(df.Pool == 'Community', 1)
.when(df.Pool == 'Private,Community', 1)
.otherwise(0))



spark.sql("set spark.sql.legacy.timeParserPolicy=LEGACY")
df = df.withColumn("Date",to_date(df.PendingDate, 'MM/dd/yyyy'))
df = df.withColumn("year",year(col("Date")))

# %%
dfp = df.toPandas()
dfp = dfp.iloc[:,[3,7,10,11,15,17,18,20,23,24,25,26,27,28,29]]

dfp.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Beds</th>
#       <th>sqft</th>
#       <th>lotsqft</th>
#       <th>yrblt</th>
#       <th>adom_agentdaysonmarket</th>
#       <th>listprice</th>
#       <th>pricesold</th>
#       <th>splsale</th>
#       <th>baths</th>
#       <th>specialsale</th>
#       <th>tileroof</th>
#       <th>privatepool</th>
#       <th>communitypool</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>1695</td>
#       <td>8694</td>
#       <td>1992</td>
#       <td>2</td>
#       <td>150000</td>
#       <td>141500</td>
#       <td>Short Sale</td>
#       <td>2.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2017-07-12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1305</td>
#       <td>6540</td>
#       <td>1992</td>
#       <td>133</td>
#       <td>179000</td>
#       <td>160000</td>
#       <td>None</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>2015-07-02</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1420</td>
#       <td>4845</td>
#       <td>1991</td>
#       <td>4</td>
#       <td>165000</td>
#       <td>161500</td>
#       <td>None</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2015-06-17</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>1598</td>
#       <td>5750</td>
#       <td>1996</td>
#       <td>44</td>
#       <td>184000</td>
#       <td>170000</td>
#       <td>None</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>2016-06-24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>2302</td>
#       <td>5390</td>
#       <td>1992</td>
#       <td>14</td>
#       <td>180000</td>
#       <td>170000</td>
#       <td>Short Sale</td>
#       <td>2.5</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2015-08-10</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #Data Visualizations

# %%
dfp[['pricesold']].hist()
# Out:
# Out[19]: array([[<AxesSubplot:title={'center':'pricesold'}>]], dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
col_log = np.log(dfp["pricesold"])
print("Skewness in Column : Log Expenses " , col_log.skew())

plt.hist(col_log)
plt.show()
# Out:
# Skewness in Column : Log Expenses  0.7616552302280692

# %%
import seaborn as sns
sns.pairplot(dfp.iloc[:,1:8],corner=True)
# Out:
# Out[24]: <seaborn.axisgrid.PairGrid at 0x7fca1e2d86a0>

# %%
dfp.iloc[:,1:7].corr()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sqft</th>
#       <th>lotsqft</th>
#       <th>yrblt</th>
#       <th>adom_agentdaysonmarket</th>
#       <th>listprice</th>
#       <th>lppersqft</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>sqft</th>
#       <td>1.000000</td>
#       <td>0.788756</td>
#       <td>0.256993</td>
#       <td>0.379431</td>
#       <td>0.909356</td>
#       <td>0.355600</td>
#     </tr>
#     <tr>
#       <th>lotsqft</th>
#       <td>0.788756</td>
#       <td>1.000000</td>
#       <td>0.277242</td>
#       <td>0.291500</td>
#       <td>0.848344</td>
#       <td>0.545763</td>
#     </tr>
#     <tr>
#       <th>yrblt</th>
#       <td>0.256993</td>
#       <td>0.277242</td>
#       <td>1.000000</td>
#       <td>0.169759</td>
#       <td>0.315727</td>
#       <td>0.208579</td>
#     </tr>
#     <tr>
#       <th>adom_agentdaysonmarket</th>
#       <td>0.379431</td>
#       <td>0.291500</td>
#       <td>0.169759</td>
#       <td>1.000000</td>
#       <td>0.332559</td>
#       <td>-0.000498</td>
#     </tr>
#     <tr>
#       <th>listprice</th>
#       <td>0.909356</td>
#       <td>0.848344</td>
#       <td>0.315727</td>
#       <td>0.332559</td>
#       <td>1.000000</td>
#       <td>0.681903</td>
#     </tr>
#     <tr>
#       <th>lppersqft</th>
#       <td>0.355600</td>
#       <td>0.545763</td>
#       <td>0.208579</td>
#       <td>-0.000498</td>
#       <td>0.681903</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dfp.iloc[:,1:7].corr())
plt.show()

# %%
dfp.columns
# Out:
# Out[115]: Index(['Beds', 'sqft', 'lotsqft', 'yrblt', 'adom_agentdaysonmarket',
#        'listprice', 'lppersqft', 'pricesold', 'splsale', 'baths',
#        'specialsale', 'tileroof', 'privatepool', 'communitypool', 'year'],
#       dtype='object')

# %% [markdown]
# #Feature Processing

# %%
# Create a 70-30 train test split

train_data,test_data=df.randomSplit([0.7,0.3])

# %%
# Import the required libraries

from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import GeneralizedLinearRegression
from pyspark.ml.feature import VectorAssembler,StringIndexer,StandardScaler
from pyspark.ml import Pipeline

# %%
# Use StringIndexer to convert the categorical columns to hold numerical data

beds_indexer = StringIndexer(inputCol="Beds",outputCol='beds_index',handleInvalid='keep')
garages_indexer = StringIndexer(inputCol="garages",outputCol="garages_index",handleInvalid='keep')
baths_indexer = StringIndexer(inputCol="baths",outputCol='baths_index',handleInvalid='keep')
year_indexer = StringIndexer(inputCol="year",outputCol="year_index",handleInvalid='keep')

# %%
assembler = VectorAssembler(inputCols=["sqft","tileroof","yrblt","privatepool","communitypool","specialsale",'beds_index',
                                      'garages_index','baths_index','year_index'],
                           outputCol="features")

# %%
# Standard scaler is used to scale the data for the linear SVC to perform well on the training data

#scaler = StandardScaler(inputCol="unscaled_features",outputCol="features")

# %%
pipe = Pipeline(stages=[beds_indexer,garages_indexer,baths_indexer,year_indexer,assembler])

# %% [markdown]
# ##Models

# %% [markdown]
# Linear Regression

# %%
fitted_pipe=pipe.fit(train_data)

# %%
train_data_lm=fitted_pipe.transform(train_data)

# %%
# Create an object for the Linear Regression model

lr_model = LinearRegression(labelCol='pricesold')

# %%
# Fit the model on the train data

fit_model = lr_model.fit(train_data_lm.select(['features','pricesold']))

# %%
print("Coefficients: %s" % str(fit_model.coefficients))
print("Intercept: %s" % str(fit_model.intercept))
print(fit_model.summary.pValues)
# Out:
# Coefficients: [136.88244278000008,0.0,638.4414100934891,425.1327301972816,9284.740759855704,11874.86485149813,2884.920473802993,2196.1828725031037,-1210.1081536683878,5157.280621781377,-23.16541013866363]
# Intercept: -1679798.033357255
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-2110609132831256> in <module>
#       1 print("Coefficients: %s" % str(fit_model.coefficients))
#       2 print("Intercept: %s" % str(fit_model.intercept))
# ----> 3 print(fit_model.summary.pValues)
#
# /databricks/spark/python/pyspark/ml/regression.py in pValues(self)
#     600         LinearRegression.solver
#     601         """
# --> 602         return self._call_java("pValues")
#     603
#     604
#
# /databricks/spark/python/pyspark/ml/wrapper.py in _call_java(self, name, *args)
#      52         sc = SparkContext._active_spark_context
#      53         java_args = [_py2java(sc, arg) for arg in args]
# ---> 54         return _java2py(sc, m(*java_args))
#      55
#      56     @staticmethod
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115     def deco(*a, **kw):
#     116         try:
# --> 117             return f(*a, **kw)
#     118         except py4j.protocol.Py4JJavaError as e:
#     119             converted = convert_exception(e.java_exception)
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     324             value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325             if answer[1] == REFERENCE_TYPE:
# --> 326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
#     328                     format(target_id, ".", name), value)
#
# Py4JJavaError: An error occurred while calling o4133.pValues.
# : java.lang.UnsupportedOperationException: No p-value available for this LinearRegressionModel
# 	at org.apache.spark.ml.regression.LinearRegressionSummary.pValues$lzycompute(LinearRegression.scala:1068)
# 	at org.apache.spark.ml.regression.LinearRegressionSummary.pValues(LinearRegression.scala:1065)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
trainingSummary = fit_model.summary
print("numIterations: %d" % trainingSummary.totalIterations)
print("objectiveHistory: %s" % str(trainingSummary.objectiveHistory))
trainingSummary.residuals.show()
print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
print("r2: %f" % trainingSummary.r2)
# Out:
# numIterations: 16
# objectiveHistory: [0.5, 0.27531045440982416, 0.04572711061138568, 0.035815648586611015, 0.012673227492651318, 0.010546043752304168, 0.01027229257618023, 0.010249389002177534, 0.010247660245056078, 0.010247436384462016, 0.010247428160462757, 0.010247427833730338, 0.01024742776449683, 0.01024742776415577, 0.010247427764141559, 0.010247427764141559, 0.010247427764141559]
# +-------------------+
# |          residuals|
# +-------------------+
# |  33701.63831186015|
# | 23968.484623747412|
# |-13986.362833898282|
# | 11962.183958906913|
# |   30071.9657573835|
# | 26730.881734928116|
# | -3176.365654058056|
# | -5985.184079262195|
# | 28273.651924925158|
# |-12294.204427857883|
# | 17724.098799904576|
# |  27336.07061251928|
# |   9650.53911751369|
# | 29751.379661502084|
# | -6412.279308504891|
# | -322.1382983413059|
# | 13781.667001302121|
# |-15825.012874227716|
# | 26680.288103322964|
# |  4390.325506569585|
# +-------------------+
# only showing top 20 rows
#
# RMSE: 21329.163696
# r2: 0.979505

# %%
# Transform the test data using the model to predict the duration

test_data_lm=fitted_pipe.transform(test_data)

# %%
# Store the results in a dataframe
results = fit_model.transform(test_data_lm)

# %%
#from pyspark.sql.functions import round, col

results_lm = results.select('pricesold', round(col('prediction')))
results_lm = results_lm.withColumnRenamed('round(prediction, 0)','prediction')
results_lm.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pricesold</th><th>prediction</th></tr></thead><tbody><tr><td>160000</td><td>180200.0</td></tr><tr><td>170000</td><td>162008.0</td></tr><tr><td>170000</td><td>155221.0</td></tr><tr><td>170000</td><td>168013.0</td></tr><tr><td>172500</td><td>165614.0</td></tr><tr><td>179000</td><td>148993.0</td></tr><tr><td>182000</td><td>146639.0</td></tr><tr><td>182500</td><td>172670.0
td>336494.0</td></tr><tr><td>345000</td><td>336595.0</td></tr><tr><td>345000</td><td>383306.0</td></tr><tr><td>347000</td><td>344556.0</td></tr><tr><td>350000</td><td>352154.0</td></tr><tr><td>355000</td><td>353207.0</td></tr><tr><td>355000</td><td>350398.0</td></tr><tr><td>357000</td><td>354555.0</td></tr><tr><td>359900</td><td>371534.0</td></tr><tr><td>360900</td><td>361891.0</td></tr><tr><td>363000</td><td>366001.0</td></tr><tr><td>365000</td><td>362602.0</td></tr><tr><td>370000</td><td>369177.0</td></tr><tr><td>374900</td><td>369576.0</td></tr><tr><td>375000< ...

# %%
from numpy import polyfit
x1 = results_lm.toPandas()['pricesold'].values.tolist()
y1 = results_lm.toPandas()['prediction'].values.tolist()
plt.scatter(x1, y1, color='red', s=30)
plt.xlabel('Pricesold')
plt.ylabel('Prediction')
plt.title('Linear Regression')
p1 = polyfit(x1, y1, 1)
plt.plot(x1, np.polyval(p1,x1), 'g-' )
plt.show()

# %%
test_results = fit_model.evaluate(test_data_lm)

# %%
test_results.residuals.show()
# Out:
# +-------------------+
# |          residuals|
# +-------------------+
# |-28236.672795304563|
# |  1106.800132652279|
# |-17785.258753179573|
# |  1931.348039579112|
# |-1637.3736494011246|
# |   3378.91095807706|
# | 15339.160233734874|
# |  24340.97230849578|
# |  33080.59036239493|
# | -7808.266339704627|
# | -12.94774848385714|
# |   20213.1580372788|
# |-20165.552272995235|
# | 14837.532657799777|
# |  39361.51079646661|
# |  22397.31136702583|
# | 16490.583115317626|
# | 16342.512067784555|
# |  2645.696201057872|
# | 16567.036283245776|
# +-------------------+
# only showing top 20 rows

# %%
test_results.rootMeanSquaredError
# Out:
# Out[183]: 18228.654824078138

# %%
test_results.r2
# Out:
# Out[184]: 0.9810491147152035

# %% [markdown]
# Generalized Linear Model

# %%
fitted_pipe=pipe.fit(train_data)

# %%
train_data_glm=fitted_pipe.transform(train_data)

# %%
glr = GeneralizedLinearRegression(labelCol='pricesold',family="poisson", link="log", maxIter=10, regParam=0.3)
fit_model = glr.fit(train_data_glm.select(['features','pricesold']))

# %%
print("Coefficients: " + str(fit_model.coefficients))
print("Intercept: " + str(fit_model.intercept))
trainingSummary = fit_model.summary
# Out:
# Coefficients: [0.00031384983151925097,0.0,-0.0032268773603926866,0.01868462707468395,-0.013691870973334748,-0.006965840790884264,0.006551631509852299,-0.013043467453420238,0.0014835885110593857,-0.01732540493086293,0.0007111717801186111]
# Intercept: 17.453713486807796
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <command-2110609132831271> in <module>
#       3 trainingSummary = fit_model.summary
#       4 #print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
# ----> 5 print("r2: %f" % trainingSummary.r2)
#
# AttributeError: 'GeneralizedLinearRegressionTrainingSummary' object has no attribute 'r2'

# %%
# Transform the test data using the model to predict the duration

test_data_glm=fitted_pipe.transform(test_data)

# %%
# Store the results in a dataframe

results = fit_model.transform(test_data_glm)

# %%
from pyspark.sql.functions import round, col

results_glm = results.select('pricesold', round(col('prediction')))
results_glm = results_glm.withColumnRenamed('round(prediction, 0)','prediction')
results_glm.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
r><tr><td>330000</td><td>323453.0</td></tr><tr><td>333500</td><td>340155.0</td></tr><tr><td>338900</td><td>348917.0</td></tr><tr><td>340000</td><td>342439.0</td></tr><tr><td>340000</td><td>316586.0</td></tr><tr><td>340000</td><td>306154.0</td></tr><tr><td>345000</td><td>335051.0</td></tr><tr><td>345000</td><td>347905.0</td></tr><tr><td>345000</td><td>341263.0</td></tr><tr><td>347000</td><td>347433.0</td></tr><tr><td>350000</td><td>347857.0</td></tr><tr><td>355000</td><td>351908.0</td></tr><tr><td>355000</td><td>350602.0</td></tr><tr><td>357000</td><td>350435.0</td></tr><tr><td>359900</td><td>358768.0</td></tr><tr><td>360900</td><td>346649.0</td></tr><tr><td>363000</td><td>355687.0</td></tr><tr><td>365000</td><td>352340.0</td></tr><tr><td>370000</td><td>361301.0</td></tr><tr><td>374900</td><td>356677.0</td></tr><tr><td>375000< ...

# %%
from numpy import polyfit
x1 = results_glm.toPandas()['pricesold'].values.tolist()
y1 = results_glm.toPandas()['prediction'].values.tolist()
plt.scatter(x1, y1, color='red', s=30)
plt.xlabel('Pricesold')
plt.ylabel('Prediction')
plt.title('Generalized Linear Regression')
p1 = polyfit(x1, y1, 1)
plt.plot(x1, np.polyval(p1,x1), 'g-' )
plt.show()

# %%
test_results = fit_model.evaluate(test_data_glm)

# %%
summary = fit_model.summary
print("AIC: " + str(summary.aic))
# Out:
# AIC: 602290.2598029431

# %% [markdown]
# Decision Tree Regression

# %%
fitted_pipe=pipe.fit(train_data)

# %%
train_data_dt=fitted_pipe.transform(train_data)

# %%
from pyspark.ml.regression import DecisionTreeRegressor
dt = DecisionTreeRegressor(labelCol='pricesold')
# Fit the model on the train data

fit_model = dt.fit(train_data_dt.select(['features','pricesold']))

# %%
#trainingSummary = fit_model.summary
#print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
#print("r2: %f" % trainingSummary.r2)

# %%
# Transform the test data using the model to predict the duration

test_data_dt=fitted_pipe.transform(test_data)

# %%
# Store the results in a dataframe

results = fit_model.transform(test_data_dt)

# %%
from pyspark.sql.functions import round, col

results_dt = results.select('pricesold', round(col('prediction')))
results_dt = results_dt.withColumnRenamed('round(prediction, 0)','prediction')
results_dt.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pricesold</th><th>prediction</th></tr></thead><tbody><tr><td>160000</td><td>233788.0</td></tr><tr><td>170000</td><td>204994.0</td></tr><tr><td>170000</td><td>226994.0</td></tr><tr><td>170000</td><td>226994.0</td></tr><tr><td>172500</td><td>204994.0</td></tr><tr><td>179000</td><td>204994.0</td></tr><tr><td>182000</td><td>204994.0</td></tr><tr><td>182500</td><td>233788.0</td></tr><tr><td>184000</td><td>204994.0</td></tr><tr><td>188000</td><td>233788.0</td></tr><tr><td>192950</td><td>204994.0</td></tr><tr><td>193000</td><td>204994.0</td></tr><tr><td>193000</td><td>204994.0</td></tr><tr><td>198000</td><td>233788.0</td></tr><tr><td>202000</td><td>226994.0</td></tr><tr><td>205000</td><td>204994.0</td></tr><tr><td>210000</td><td>204994.0</td></tr><tr><td>210000</td><td>204994.0</td></tr><tr><td>215000</td><td>306759.0</td></tr><tr><td>215500</td><td>204994.0</td></tr><tr><td>215800</td><td>226994.0</td></t
# %%
from numpy import polyfit
x1 = results_dt.toPandas()['pricesold'].values.tolist()
y1 = results_dt.toPandas()['prediction'].values.tolist()
plt.scatter(x1, y1, color='red', s=30)
plt.xlabel('Pricesold')
plt.ylabel('Prediction')
plt.title('Decision Tree')
p1 = polyfit(x1, y1, 1)
plt.plot(x1, np.polyval(p1,x1), 'g-' )
plt.show()

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(
    labelCol="pricesold", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(results)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 49442.6

# %%
y_true = results.select("pricesold").toPandas()
y_pred = results.select("prediction").toPandas()

import sklearn.metrics
r2_score = sklearn.metrics.r2_score(y_true, y_pred)
print('r2_score: {0}'.format(r2_score))
# Out:
# r2_score: 0.8605808047868821

# %% [markdown]
# Random Forest Regression

# %%
fitted_pipe=pipe.fit(train_data)

# %%
train_data_rf=fitted_pipe.transform(train_data)

# %%
from pyspark.ml.regression import RandomForestRegressor
rf = RandomForestRegressor(featuresCol="features",labelCol="pricesold")

# %%
fit_model = rf.fit(train_data_rf.select(['features','pricesold']))

# %%
# Transform the test data using the model to predict the duration

test_data_rf=fitted_pipe.transform(test_data)

# %%
# Store the results in a dataframe

results = fit_model.transform(test_data_rf)

# %%
from pyspark.sql.functions import round, col

results_rf = results.select('pricesold', round(col('prediction')))
results_rf = results_rf.withColumnRenamed('round(prediction, 0)','prediction')
results_rf.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pricesold</th><th>prediction</th></tr></thead><tbody><tr><td>160000</td><td>226698.0</td></tr><tr><td>170000</td><td>210724.0</td></tr><tr><td>170000</td><td>244287.0</td></tr><tr><td>170000</td><td>240866.0</td></tr><tr><td>172500</td><td>221454.0</td></tr><tr><td>179000</td><td>221801.0</td></tr><tr><td>182000</td><td>215163.0</td></tr><tr><td>182500</td><td>226698.0</td></tr><tr><td>184000</td><td>220504.0</td></tr><tr><td>188000</td><td>245426.0</td></tr><tr><td>192950</td><td>213163.0</td></tr><tr><td>193000</td><td>215608.0</td></tr><tr><td>193000</td><td>213760.0</td></tr><tr><td>198000</td><td>227012.0</td></tr><tr><td>202000</td><td>258696.0</td></tr><tr><td>205000</td><td>215453.0</td></tr><tr><td>210000</td><td>226616.0</td></tr><tr><td>210000</td><td>223559.0</td></tr><tr><td>215000</td><td>295594.0</td></tr><tr><td>215500</td><td>229072.0</td></tr><tr><td>215800</td><td>247369.0</td></tr><tr><td>216000</td><td>223009.0</td></tr><tr><td>217000</td><td>223499.0</td></tr><tr><td>219000</td><td>270624.0</td></tr><tr><td>220000</td><td>226884.0</td></tr><tr><td>224000</td><td>236847.0</td></tr><tr><td>224500</td><td>222357.0</td></tr><tr><td>227000</td><td>308747.0</td></tr><tr><td>230000</td><td>241189.0</td></tr><tr><td>230000</td><td>275051.0</td></tr><tr><td>234000</td><td>247805.0</td></tr><tr><td>234500</td><td>225906.0</td></tr><tr><td>235000</td><td>231495.0</td></tr><tr><td>235000</td><td>247163.0</td></tr><tr><td>237500</td><td>254216.0</td></tr><tr><td>239000</td><td>241117.0</td></tr><tr><td>240000</td><td>236186.0</td></tr><tr><td>240500</td><td>226044.0</td></tr><tr><td>245000</td><td>246612.0</td></tr><tr><td>245000</td><td>239263.0</td></tr><tr><td>249000</td><td>234107.0</td></tr><tr><td>249000</td><td>238951.0</td></tr><tr><td>249000</td><td>273962.0</td></tr><tr><td>250000</td><td>300526.0</td></tr><tr><td>251500</td><td>228148.0</td></tr><tr><td>254000</td><td>256423.0</td></tr><tr><td>258000</td><td>275191.0</td></tr><tr><td>265000</td><td>300452.0</td></tr><tr><td>267000</td><td>297556.0</td></tr><tr><td>269900</td><td>290912.0</td></tr><tr><td>269999</td><td>259410.0</td></tr><tr><td>270000</td><td>263269.0</td></tr><tr><td>271500</td><td>249254.0</td></tr><tr><td>280000</td><td>305213.0</td></tr><tr><td>285000</td><td>338312.0</td></tr><tr><td>285000</td><td>306745.0</td></tr><tr><td>287000</td><td>305130.0</td></tr><tr><td>290000</td><td>308179.0</td></tr><tr><td>294000</td><td>347971.0</td></tr><tr><td>295000</td><td>377465.0</td></tr><tr><td>297500</td><td>306071.0</td></tr><tr><td>299000</td><td>342461.0</td></tr><tr><td>299500</td><td>259514.0</td></tr><tr><td>302500</td><td>298425.0</td></tr><tr><td>307500</td><td>308179.0</td></tr><tr><td>311000</td><td>308059.0</td></tr><tr><td>322500</td><td>370841.0</td></tr><tr><td>323000</td><td>439762.0</td></tr><tr><td>327500</td><td>339879.0</td></tr><tr><td>328000</td><td>318738.0</td></tr><tr><td>330000</td><td>354270.0</td></tr><tr><td>330000</td><td>325221.0</td></tr><tr><td>330000</td><td>352955.0</td></tr><tr><td>330000</td><td>346190.0</td></tr><tr><td>333500</td><td>351895.0</td></tr><tr><td>338900</td><td>441184.0</td></tr><tr><td>340000</td><td>331281.0</td></tr><tr><td>340000</td><td>349589.0</td></tr><tr><td>340000</td><td>395876.0</td></tr><tr><td>345000</td><td>340674.0</td></tr><tr><td>345000</td><td>336411.0</td></tr><tr><td>345000</td><td>435811.0</td></tr><tr><td>347000</td><td>359426.0</td></tr><tr><td>350000</td><td>353709.0</td></tr><tr><td>355000</td><td>352305.0</td></tr><tr><td>355000</td><td>359426.0</td></tr><tr><td>357000</td><td>345230.0</td></tr><tr><td>359900</td><td>312916.0</td></tr><tr><td>360900</td><td>364954.0</td></tr><tr><td>363000</td><td>363010.0</td></tr><tr><td>365000</td><td>376147.0</td></tr><tr><td>370000</td><td>347898.0</td></tr><tr><td>374900</td><td>366884.0</td></tr><tr><td>375000< ...

# %%
from numpy import polyfit
x1 = results_rf.toPandas()['pricesold'].values.tolist()
y1 = results_rf.toPandas()['prediction'].values.tolist()
plt.scatter(x1, y1, color='red', s=30)
plt.xlabel('Pricesold')
plt.ylabel('Prediction')
plt.title('Random Forest')
p1 = polyfit(x1, y1, 1)
plt.plot(x1, np.polyval(p1,x1), 'g-' )
plt.show()

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(
    labelCol="pricesold", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(results)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 40730.7

# %%
y_true = results.select("pricesold").toPandas()
y_pred = results.select("prediction").toPandas()

import sklearn.metrics
r2_score = sklearn.metrics.r2_score(y_true, y_pred)
print('r2_score: {0}'.format(r2_score))
# Out:
# r2_score: 0.9053840915299745

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
